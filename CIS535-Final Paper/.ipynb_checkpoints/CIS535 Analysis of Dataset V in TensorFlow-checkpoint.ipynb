# %% [markdown]
# # Analysis of Dataset "V"
#
# **Dec 08, 2016** - Cole R Lawrence
#
#
# ## Introduction
#
# This is an analysis of the dataset "V.txt" provided by Professor Randall Sexton, of Missouri State University.
#
# Many parts of this process have been guided by the walkthrough provided by a portion of the [TensorFlow-r0.12 input_fn tutorial](https://www.tensorflow.org/versions/r0.12/tutorials/input_fn/index.html#a-neural-network-model-for-boston-house-values)
#
# The data is a 10 feature column, 1 label column, normallized set of records, that we will describe as feature columns: `a`, `b`, `c`, `d`, `e`, `f`, `g`, `h`, `i`, and `j`; and label column: `label`.
#
# A sample of this data is observed as:
#
# |a|b|c|d|e|f|g|h|i|j|label|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0.964832001|0.167608408|0.785817575|0.973900572|0.827656451|0.723247695|0.168019645|0.92963043|0.343092062|0.459721361|-0.063214333|
# |0.350357937|0.537658157|0.66599431|0.624714366|0.551134075|0.480008969|0.370674242|0.326656695|0.650401706|0.889828407|-0.497172847|
# |0.729416637|0.134511402|0.578864851|0.97313488|0.629550866|0.137757748|0.078562116|0.428373963|0.11179501|0.227544019|-0.004078776|
# |0.597451448|0.695044826|0.661880205|0.371318889|0.419261914|0.666476433|0.272743624|0.695244983|0.180037305|0.274409075|-0.411909897|
# |0.81788859|0.308970538|0.885182085|0.954469775|0.180395136|0.159075865|0.915095901|0.855763426|0.177076622|0.154224171|-0.379670109|
#
# ### Goals
#
# Our first goal is to train a neural network to take the feature columns to predict our label value of the last column.
#
# We will use some python here to automate a tenfold cross validation and observe the differences in accurracy as we perform each step. Our primary data file lies in `./data/v.txt` which we will generate our 10 training and 10 test sets with.
#
# A final goal of this analysis shall include evaluating the significance of each feature column in the final prediction.

# %% [markdown]
# ## Outline
#
# We will take several steps to analyze our data, so this is a quick overview of each thing we will do.
#
#  1. Set up our imports and dependencies
#  2. [Describing Data Features](#Describing-Data-Features)
#     Name our columns and create an input_fn for TensorFlow's regressor model to use.
#  3. [Creating Regressor](#Creating-Regressor)
#     Create a regressor model with the input_fn.
#  4. [Reading in Data](#Reading-in-Data) Create test sets and training sets from data for a tenfold cross validation.
#  5. [Training and Testing](#Training-and-Testing) Process training and test sets through the model, and collect accuracy metrics for each iteration.
#  6. [Input Sensitivity](#Input-Sensitivity) Analyze outcomes.
#  7. [Conclusion](#Conclusion) Conclusion with observations of sensitivities.

# %% [markdown]
# ## Dependencies
#
# These libraries will help us import and label our data columns and traverse our data structure when establishing an input function and providing it to our regressor.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import pandas as pd
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

# %% [markdown]
# ## Describing Data Features
#
# Other csv formatted data files were originally created for initial (non-tenfold cross validated) process:
# ```py
# V_TRAINING = "data/v_training.csv"
# V_TEST     = "data/v_test.csv"
# V_PREDICT  = "data/v_predict.csv"
# ```

# %%
# Data set files
V_DATA = "data/v.txt"

# We do not know exactly what our data represents,
# but we do know our label is the last column.
COLUMNS  = "a b c d e f g h i j label".split(" ")
FEATURES = COLUMNS[:-1]
LABEL    = COLUMNS[-1]

print("COLUMNS", COLUMNS)
print("FEATURES", FEATURES)
print("LABEL", LABEL)
# Out:
# COLUMNS ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'label']
# FEATURES ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# LABEL label

# %% [markdown]
# ### Feature Columns
#
# Now that we have our data, we will create a list of `FeatureColumn` for the input data.
#
# All of our columns consist of continuous values, so we may declare all of them using:
#
# ```python
# feature_cols = [tf.contrib.layers.real_valued_column(k)
#                   for k in FEATURES]
# ```

# %%
feature_cols = [tf.contrib.layers.real_valued_column(k)
                for k in FEATURES]

# %% [markdown]
# ## Creating Regressor
#
# And, we can create our regressor.
#
# > Now, instantiate a `DNNRegressor` for the neural network regression model. You'll need to provide two arguments here: `hidden_units`, a hyperparameter specifying the number of nodes in each hidden layer (here, two hidden layers with 10 nodes each), and `feature_columns`, containing the list of FeatureColumns you just defined:
#
# Here, we can also define our activation function by passing in `activation_fn=relu`
#
# API Docs: [DNNRegressor class](https://www.tensorflow.org/versions/r0.12/api_docs/python/contrib.learn.html#DNNRegressor)

# %%
# Here we are specifying 2 hidden layers, of sizes 20, and 10.

regressor = tf.contrib.learn.DNNRegressor( 
    feature_columns=feature_cols, hidden_units=[10, 10])
# We can later store our model data here, thus allowing us to use our network in other applications.
#     model_dir='./model-data'
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia
# WARNING:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, 'keep_checkpoint_max': 5, 'save_summary_steps': 100, 'task': 0, 'master': '', 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , 'num_ps_replicas': 0, 'tf_random_seed': None, 'evaluation_master': '', '_job_name': None, 'cluster_spec': None, 'keep_checkpoint_every_n_hours': 10000, 'save_checkpoints_secs': 600}

# %% [markdown]
# ### Input Function (`input_fn`)
#
# The body of the input function contains the specific logic for preprocessing your input data, such as scrubbing out bad examples or feature scaling.
#
# Also, in our case it takes in a pandas `DateFrame` and sorts it out between features and labels for TensorFlow to train, evaluate, and predict with.
#
# It returns a tuple such as `(feature_tensors, label_tensors)`

# %%
def input_fn(data_set):
    # Values of feature columns
    feature_cols = {k: tf.constant(data_set[k].values)
                    for k in FEATURES }
    # Return the label values of the passed data_set
    labels = tf.constant(data_set[LABEL].values)
    
    # Return your data split apart for the Regressor,
    # This allows the columns to be any order, and to quickly change which
    # columns you want to observe.
    return feature_cols, labels

# %% [markdown]
# ## Reading in Data
#
# Let's create our tenfold cross validation so we can train and test our model!

# %%
# Read in data

data_set = pd.read_table(V_DATA, skipinitialspace=True,
                         skiprows=0, names=COLUMNS)

# Printing is an advantage of pandas
print("First three rows of v.txt data")
print(data_set[:3])
# Out:
# First three rows of v.txt data
#           a         b         c         d         e         f         g  \
# 0  0.964832  0.167608  0.785818  0.973901  0.827656  0.723248  0.168020
# 1  0.350358  0.537658  0.665994  0.624714  0.551134  0.480009  0.370674
# 2  0.729417  0.134511  0.578865  0.973135  0.629551  0.137758  0.078562
#
#           h         i         j     label
# 0  0.929630  0.343092  0.459721 -0.063214
# 1  0.326657  0.650402  0.889828 -0.497173
# 2  0.428374  0.111795  0.227544 -0.004079

# %% [markdown]
# 413  0.430169  0.099673  0.025762 -0.862095
# 414  0.714442  0.490052  0.649673 -0.541029
# 415  0.691562  0.095741  0.555468 -0.560621
# 416  0.890088  0.883429  0.067909  0.092376
# 417  0.192453  0.605762  0.857157  0.131393
# 418  0.097274  0.998222  0.402593  0.464175
# 419  0.325777  0.235185  0.808044 -0.405594
# 420  0.415806  0.871901  0.620062 -0.057130
# 421  0.161394  0.082270  0.313794 -0.304028
# 422  0.593866  0.149953  0.433868  0.020524
# 423  0.679011  0.907896  0.647324  0.356452
# 424  0.611349  0.484099  0.899350 -0.726649
# 425  0.010680  0.794424  0.358136 -0.283702
# 426  0.589787  0.120725  0.082763  0.089481
# 427  0.621534  0.660721  0.885406  0.104719
# 428  0.471344  0.683197  0.832341 -0.004739
# 429  0.649718  0.925495  0.657432  0.266195
# ..        ...       ...       ...       ...
# 470  0.614803  0.769299  0.241153 -0.766841
# 471  0.902949  0.532755  0.490167  0.123787
# 472  0.194687  0.430398  0.325084  0.175907
# 473  0.137904  0.574220  0.989720  0.222267
# 474  0.079305  0.429979  0.955117 -0.745556
# 475  0.591530  0.588596  0.350799 -0.233512
# 476  0.064260  0.915969  0.610506 -0.337940
# 477  0.475553  0.258694  0.407549 -0.067052
# 478  0.386423  0.277862  0.311206 -0.894041
# 479  0.808761  0.602208  0.471769 -0.259369
# 480  0.151840  0.549926  0.238436  0.090556
# 481  0.704495  0.423165  0.771668 -0.362230
# 482  0.973716  0.129650  0.141360  0.133666
# 483  0.584916  0.792199  0.960506  0.178425
# 484  0.508560  0.517715  0.463266 -0.095965
# 485  0.958593  0.005944  0.781267 -0.428054
# 486  0.531188  0.165754  0.156271 -0.038334
# 487  0.020721  0.161378  0.186689 -0.127188
# 488  0.636770  0.054251  0.272374 -0.368436
# 489  0.089736  0.671574  0.769372 -0.362095
# 490  0.124394  0.286279  0.414439 -0.692057
# 491  0.725737  0.959754  0.140768 -0.382184
# 492  0.750347  0.024122  0.376248 -0.392979
# 493  0.619149  0.157613  0.513092 -0.216665
# 494  0.581725  0.979334  0.299277  0.116743
# 495  0.809388  0.482350  0.239982 -0.276290
# 496  0.314887  0.236322  0.658718 -0.254327
# 497  0.055863  0.089625  0.912889 -0.129048
# 498  0.937400  0.947868  0.220407 -0.344192
# 499  0.664275  0.576937  0.691410 -0.486597
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Training and Testing

# %%
def train_and_test(n):
    train_set(n)
    ev = test_set(n)
    return ev

def train_set(n, steps = 500):
    (training_set, _) = rotations[n]
    regressor.fit(input_fn=lambda: input_fn(training_set), steps=steps)

def test_set(n):
    (_, test_set) = rotations[n]
    return regressor.evaluate(input_fn=lambda: input_fn(test_set), steps=1)

# %%
test_results = [train_and_test(n) for n in range(10)]
# Out:
# INFO:tensorflow:Setting feature info to {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'f': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'h': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'd': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'e': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'i': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'j': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'g': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}
# INFO:tensorflow:Setting targets info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='d', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='e', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='f', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='g', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='h', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='i', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='j', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.275019, step = 1
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia/model.ckpt.
# INFO:tensorflow:loss = 0.00733313, step = 101
# INFO:tensorflow:loss = 0.00358063, step = 201
# INFO:tensorflow:loss = 0.00272615, step = 301
# INFO:tensorflow:loss = 0.00220889, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.
 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia/model.ckpt.
# INFO:tensorflow:loss = 0.000444188, step = 4601
# INFO:tensorflow:loss = 0.00044258, step = 4701
# INFO:tensorflow:loss = 0.000441488, step = 4801
# INFO:tensorflow:loss = 0.000440519, step = 4901
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000439707.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'h': <tf.Tensor 'Const_7:0' shape=(100,) dtype=float64>, 'e': <tf.Tensor 'Const_4:0' shape=(100,) dtype=float64>, 'd': <tf.Tensor 'Const_3:0' shape=(100,) dtype=float64>, 'i': <tf.Tensor 'Const_8:0' shape=(100,) dtype=float64>, 'g': <tf.Tensor 'Const_6:0' shape=(100,) dtype=float64>, 'j': <tf.Tensor 'Const_9:0' shape=(100,) dtype=float64>, 'f': <tf.Tensor 'Const_5:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'f': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'h': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'd': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'e': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'i': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'j': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'g': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_10:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='d', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='e', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='f', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='g', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='h', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='i', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='j', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia
# INFO:tensorflow:Eval steps [0,1) for training step 5000.
# INFO:tensorflow:Saving evaluation summary for 5000 step: loss = 0.000482634

# %%
test_results
# Out:
# [{'global_step': 500, 'loss': 0.0030937803},
#  {'global_step': 1000, 'loss': 0.00075677177},
#  {'global_step': 1500, 'loss': 0.00071707281},
#  {'global_step': 2000, 'loss': 0.00061823113},
#  {'global_step': 2500, 'loss': 0.00069986773},
#  {'global_step': 3000, 'loss': 0.00037523161},
#  {'global_step': 3500, 'loss': 0.00048462857},
#  {'global_step': 4000, 'loss': 0.00043337338},
#  {'global_step': 4500, 'loss': 0.00049234653},
#  {'global_step': 5000, 'loss': 0.00048263368}]

# %% [markdown]
# ### Initial Impressions
#
# `test_results` resulted in the following output with settings `steps=500` for training.
#
# ```json
# [{'global_step': 500, 'loss': 0.0049484773},
#  {'global_step': 1000, 'loss': 0.0028080407},
#  {'global_step': 1500, 'loss': 0.0033099845},
#  {'global_step': 2000, 'loss': 0.0041473466},
#  {'global_step': 2500, 'loss': 0.0034174209},
#  {'global_step': 3000, 'loss': 0.0028866369},
#  {'global_step': 3500, 'loss': 0.0012178902},
#  {'global_step': 4000, 'loss': 0.0014541715},
#  {'global_step': 4500, 'loss': 0.00085818587},
#  {'global_step': 5000, 'loss': 0.00053230755}]
# ```
#
# From this output, we can see that the loss decreases over the course of these steps, but perhaps more significantly, by using a tenfold cross validation, we can ensure that we are distributing the data evenly over the neural network, so no specific pieces of the data cause our network to memorize values.
#
# Let's analyze our newly trained neural network to see if we can find relationships in our data.

# %% [markdown]
# ## Input Sensitivity
#
# To figure out which inputs are important, we are going to have our neural network make
# predictions based upon minimum and maximum values.
#
# So, to do this we will create an observation that is the average of our `data_set`, which should be very straight forward with the `pandas` library.
#
# Then, with this `control_record`, we will create a new set of records that each modify one column of this `control_record` to that column's minimum observation value, and then another with that column's maximum observation value. Each changed record shall be observed on how the column change affects the prediction value.

# %%
# Create mean record as control
control_record = data_set.mean()

# Visualize
pd.DataFrame.from_records([control_record])
# Out:
#           a         b        c         d         e         f         g  \
# 0  0.505435  0.492332  0.50105  0.504298  0.495572  0.500407  0.496272
#
#           h         i         j     label
# 0  0.511764  0.499709  0.488543 -0.222186

# %%
maxes_record = data_set.max()
mins_record = data_set.min()

# %%
# Visualize
pd.DataFrame.from_records([maxes_record])
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.998564  0.999252  0.999702  0.999379  0.999938  0.998225  0.999472
#
#           h         i         j     label
# 0  0.999618  0.999435  0.999376  0.931605

# %%
# Visualize
pd.DataFrame.from_records([mins_record])
# Out:
#          a         b         c         d         e         f         g  \
# 0  0.00132  0.001939  0.001621  0.000096  0.000735  0.000441  0.002016
#
#           h         i         j     label
# 0  0.000324  0.000276  0.000098 -0.996199

# %%
sensitivity_tests = list()
# We are going to keep track of the labels for each record we add as well.
sensitivity_set_titles = list()

sensitivity_tests.append(control_record)
sensitivity_set_titles.append("AVG Control")

for k in FEATURES:
    n_min_record = control_record.copy()
    n_min_record[k] = mins_record[k]
    n_max_record = control_record.copy()
    n_max_record[k] = maxes_record[k]
    
    # Add min and max changed records to sensitivty tests list
    sensitivity_tests.append(n_min_record)
    sensitivity_set_titles.append("MIN {0}".format(k))
    sensitivity_tests.append(n_max_record)
    sensitivity_set_titles.append("MAX {0}".format(k))

sensitivity_set = pd.DataFrame.from_records(sensitivity_tests)

# Visualize
sensitivity_set
# Out:
#            a         b         c         d         e         f         g  \
# 0   0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 1   0.001320  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 2   0.998564  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 3   0.505435  0.001939  0.501050  0.504298  0.495572  0.500407  0.496272
# 4   0.505435  0.999252  0.501050  0.504298  0.495572  0.500407  0.496272
# 5   0.505435  0.492332  0.001621  0.504298  0.495572  0.500407  0.496272
# 6   0.505435  0.492332  0.999702  0.504298  0.495572  0.500407  0.496272
# 7   0.505435  0.492332  0.501050  0.000096  0.495572  0.500407  0.496272
# 8   0.505435  0.492332  0.501050  0.999379  0.495572  0.500407  0.496272
# 9   0.505435  0.492332  0.501050  0.504298  0.000735  0.500407  0.496272
# 10  0.505435  0.492332  0.501050  0.504298  0.999938  0.500407  0.496272
# 11  0.505435  0.492332  0.501050  0.504298  0.495572  0.000441  0.496272
# 12  0.505435  0.492332  0.501050  0.504298  0.495572  0.998225  0.496272
# 13  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.002016
# 14  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.999472
# 15  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 16  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 17  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 18  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 19  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
# 20  0.505435  0.492332  0.501050  0.504298  0.495572  0.500407  0.496272
#
#            h         i         j     label
# 0   0.511764  0.499709  0.488543 -0.222186
# 1   0.511764  0.499709  0.488543 -0.222186
# 2   0.511764  0.499709  0.488543 -0.222186
# 3   0.511764  0.499709  0.488543 -0.222186
# 4   0.511764  0.499709  0.488543 -0.222186
# 5   0.511764  0.499709  0.488543 -0.222186
# 6   0.511764  0.499709  0.488543 -0.222186
# 7   0.511764  0.499709  0.488543 -0.222186
# 8   0.511764  0.499709  0.488543 -0.222186
# 9   0.511764  0.499709  0.488543 -0.222186
# 10  0.511764  0.499709  0.488543 -0.222186
# 11  0.511764  0.499709  0.488543 -0.222186
# 12  0.511764  0.499709  0.488543 -0.222186
# 13  0.511764  0.499709  0.488543 -0.222186
# 14  0.511764  0.499709  0.488543 -0.222186
# 15  0.000324  0.499709  0.488543 -0.222186
# 16  0.999618  0.499709  0.488543 -0.222186
# 17  0.511764  0.000276  0.488543 -0.222186
# 18  0.511764  0.999435  0.488543 -0.222186
# 19  0.511764  0.499709  0.000098 -0.222186
# 20  0.511764  0.499709  0.999376 -0.222186

# %%
y = regressor.predict(input_fn=lambda: input_fn(sensitivity_set), as_iterable=False)
# Out:
# WARNING:tensorflow:Calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='d', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='e', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='f', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='g', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='h', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='i', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='j', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Loading model from checkpoint: /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpg0z8vvia/model.ckpt-5000-?????-of-00001.

# %%
titles = sensitivity_set_titles
#l = [(y[i] for i in range(len(y))]

control_prediction = control_record[LABEL]
sens = [(p - control_prediction)**2 for p in y]

r = pd.DataFrame({"Prediction": y, "Sensitivity": sens})
r = r.rename_axis(lambda i: titles[i])
r
# Out:
#              Prediction  Sensitivity
# AVG Control   -0.266352     0.001951
# MIN a         -0.478032     0.065458
# MAX a          0.027617     0.062401
# MIN b         -0.004348     0.047453
# MAX b         -0.330185     0.011664
# MIN c          0.232502     0.206741
# MAX c         -0.765523     0.295216
# MIN d         -0.269283     0.002218
# MAX d         -0.263474     0.001705
# MIN e         -0.264039     0.001752
# MAX e         -0.267144     0.002021
# MIN f         -0.267731     0.002074
# MAX f         -0.263077     0.001672
# MIN g         -0.267697     0.002071
# MAX g         -0.264983     0.001832
# MIN h         -0.267582     0.002061
# MAX h         -0.264815     0.001817
# MIN i         -0.268818     0.002175
# MAX i         -0.263885     0.001739
# MIN j         -0.264679     0.001806
# MAX j         -0.267580     0.002061

# %% [markdown]
# ### Most Sensitive Columns
#
# From the above table, we can order the results by sensitivity to see which columns have the most influence in our neural network.

# %%
r.sort_values("Sensitivity", ascending=False)
# Out:
#              Prediction  Sensitivity
# MAX c         -0.765523     0.295216
# MIN c          0.232502     0.206741
# MIN a         -0.478032     0.065458
# MAX a          0.027617     0.062401
# MIN b         -0.004348     0.047453
# MAX b         -0.330185     0.011664
# MIN d         -0.269283     0.002218
# MIN i         -0.268818     0.002175
# MIN f         -0.267731     0.002074
# MIN g         -0.267697     0.002071
# MIN h         -0.267582     0.002061
# MAX j         -0.267580     0.002061
# MAX e         -0.267144     0.002021
# AVG Control   -0.266352     0.001951
# MAX g         -0.264983     0.001832
# MAX h         -0.264815     0.001817
# MIN j         -0.264679     0.001806
# MIN e         -0.264039     0.001752
# MAX i         -0.263885     0.001739
# MAX d         -0.263474     0.001705
# MAX f         -0.263077     0.001672

# %% [markdown]
# ## Conclusion
#
#
# Based on the results of this study, weresolved with an final loss of `0.00053230755`, and the only columns which seemed to have any influence in our study were columns `a` and `c`.
#
# We can test this further by doing everything again and specifying different feature columns.

# %% [markdown]
# ### Just A, B, and C

# %%
FEATURES2 = ['a', 'b', 'c']
feature_cols2 = [tf.contrib.layers.real_valued_column(k)
                for k in FEATURES2]
regressor2 = tf.contrib.learn.DNNRegressor( 
    feature_columns=feature_cols2, hidden_units=[10, 10])

def input_fn2(data_set):
    # Values of feature columns
    feature_cols = {k: tf.constant(data_set[k].values)
                    for k in FEATURES2 }
    # Return the label values of the passed data_set
    labels = tf.constant(data_set[LABEL].values)
    
    # Return your data split apart for the Regressor,
    # This allows the columns to be any order, and to quickly change which
    # columns you want to observe.
    return feature_cols, labels

def train_and_test2(n):
    train_set2(n)
    ev = test_set2(n)
    return ev

def train_set2(n, steps = 500):
    (training_set, _) = rotations[n]
    regressor2.fit(input_fn=lambda: input_fn2(training_set), steps=steps)

def test_set2(n):
    (_, test_set) = rotations[n]
    return regressor2.evaluate(input_fn=lambda: input_fn2(test_set), steps=1)

test_results2 = [train_and_test2(n) for n in range(10)]
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# WARNING:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, 'keep_checkpoint_max': 5, 'save_summary_steps': 100, 'task': 0, 'master': '', 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , 'num_ps_replicas': 0, 'tf_random_seed': None, 'evaluation_master': '', '_job_name': None, 'cluster_spec': None, 'keep_checkpoint_every_n_hours': 10000, 'save_checkpoints_secs': 600}
# INFO:tensorflow:Setting feature info to {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}
# INFO:tensorflow:Setting targets info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0777197, step = 1
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.00236951, step = 101
# INFO:tensorflow:loss = 0.00113033, step = 201
# INFO:tensorflow:loss = 0.000814772, step = 301
# INFO:tensorflow:loss = 0.000676383, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000603604.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 500.
# INFO:tensorflow:Saving evaluation summary for 500 step: loss = 0.0008946
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000643679, step = 501
# INFO:tensorflow:Saving checkpoints for 501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000715192, step = 601
# INFO:tensorflow:loss = 0.000547443, step = 701
# INFO:tensorflow:loss = 0.000523021, step = 801
# INFO:tensorflow:loss = 0.000531983, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000498193.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 1000.
# INFO:tensorflow:Saving evaluation summary for 1000 step: loss = 0.000508167
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000490825, step = 1001
# INFO:tensorflow:Saving checkpoints for 1001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.00047115, step = 1101
# INFO:tensorflow:loss = 0.000462489, step = 1201
# INFO:tensorflow:loss = 0.000487549, step = 1301
# INFO:tensorflow:loss = 0.000436772, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000426803.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 1500.
# INFO:tensorflow:Saving evaluation summary for 1500 step: loss = 0.0004727
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000429708, step = 1501
# INFO:tensorflow:Saving checkpoints for 1501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000413736, step = 1601
# INFO:tensorflow:loss = 0.000403716, step = 1701
# INFO:tensorflow:loss = 0.000395693, step = 1801
# INFO:tensorflow:loss = 0.000407409, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000388489.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 2000.
# INFO:tensorflow:Saving evaluation summary for 2000 step: loss = 0.00039083
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000384525, step = 2001
# INFO:tensorflow:Saving checkpoints for 2001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000378011, step = 2101
# INFO:tensorflow:loss = 0.000373725, step = 2201
# INFO:tensorflow:loss = 0.000361066, step = 2301
# INFO:tensorflow:loss = 0.000355821, step = 2401
# INFO:tensorflow:Saving checkpoints for 2500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000350692.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 2500.
# INFO:tensorflow:Saving evaluation summary for 2500 step: loss = 0.00038298
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.00034965, step = 2501
# INFO:tensorflow:Saving checkpoints for 2501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000346191, step = 2601
# INFO:tensorflow:loss = 0.000343562, step = 2701
# INFO:tensorflow:loss = 0.000342459, step = 2801
# INFO:tensorflow:loss = 0.000339215, step = 2901
# INFO:tensorflow:Saving checkpoints for 3000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000334171.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 3000.
# INFO:tensorflow:Saving evaluation summary for 3000 step: loss = 0.000386489
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000336916, step = 3001
# INFO:tensorflow:Saving checkpoints for 3001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000331625, step = 3101
# INFO:tensorflow:loss = 0.000328409, step = 3201
# INFO:tensorflow:loss = 0.000326194, step = 3301
# INFO:tensorflow:loss = 0.00032422, step = 3401
# INFO:tensorflow:Saving checkpoints for 3500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00032227.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 3500.
# INFO:tensorflow:Saving evaluation summary for 3500 step: loss = 0.000343833
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000328019, step = 3501
# INFO:tensorflow:Saving checkpoints for 3501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000326157, step = 3601
# INFO:tensorflow:loss = 0.000322792, step = 3701
# INFO:tensorflow:loss = 0.000320142, step = 3801
# INFO:tensorflow:loss = 0.000318086, step = 3901
# INFO:tensorflow:Saving checkpoints for 4000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0003167.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 4000.
# INFO:tensorflow:Saving evaluation summary for 4000 step: loss = 0.000312096
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000326307, step = 4001
# INFO:tensorflow:Saving checkpoints for 4001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000324449, step = 4101
# INFO:tensorflow:loss = 0.000339368, step = 4201
# INFO:tensorflow:loss = 0.000333447, step = 4301
# INFO:tensorflow:loss = 0.000318903, step = 4401
# INFO:tensorflow:Saving checkpoints for 4500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000317088.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 4500.
# INFO:tensorflow:Saving evaluation summary for 4500 step: loss = 0.000227753
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(900,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(900,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.000307998, step = 4501
# INFO:tensorflow:Saving checkpoints for 4501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:loss = 0.000306014, step = 4601
# INFO:tensorflow:loss = 0.000304383, step = 4701
# INFO:tensorflow:loss = 0.000302864, step = 4801
# INFO:tensorflow:loss = 0.0003014, step = 4901
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000300023.
# WARNING:tensorflow:Given features: {'b': <tf.Tensor 'Const_1:0' shape=(100,) dtype=float64>, 'a': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>, 'c': <tf.Tensor 'Const_2:0' shape=(100,) dtype=float64>}, required signatures: {'b': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'a': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False), 'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_3:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='a', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='b', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmpvrmzc6i7
# INFO:tensorflow:Eval steps [0,1) for training step 5000.
# INFO:tensorflow:Saving evaluation summary for 5000 step: loss = 0.000314427

# %%
test_results2
# Out:
# [{'global_step': 500, 'loss': 0.00089460023},
#  {'global_step': 1000, 'loss': 0.00050816737},
#  {'global_step': 1500, 'loss': 0.00047270037},
#  {'global_step': 2000, 'loss': 0.00039082961},
#  {'global_step': 2500, 'loss': 0.00038297984},
#  {'global_step': 3000, 'loss': 0.0003864888},
#  {'global_step': 3500, 'loss': 0.00034383262},
#  {'global_step': 4000, 'loss': 0.00031209615},
#  {'global_step': 4500, 'loss': 0.00022775274},
#  {'global_step': 5000, 'loss': 0.00031442696}]

# %% [markdown]
# Now, we can contrast that with just `C` to compare the losses for each model.

# %% [markdown]
# ## Just C

# %%
FEATURESC = ['c']
feature_cols3 = [tf.contrib.layers.real_valued_column(k)
                for k in FEATURESC]
regressor3 = tf.contrib.learn.DNNRegressor( 
    feature_columns=feature_cols3, hidden_units=[10, 10])

def input_fn3(data_set):
    # Values of feature columns
    feature_cols = {k: tf.constant(data_set[k].values)
                    for k in FEATURESC }
    # Return the label values of the passed data_set
    labels = tf.constant(data_set[LABEL].values)
    
    # Return your data split apart for the Regressor,
    # This allows the columns to be any order, and to quickly change which
    # columns you want to observe.
    return feature_cols, labels

def train_and_test3(n):
    train_set3(n)
    ev = test_set3(n)
    return ev

def train_set3(n, steps = 500):
    (training_set, _) = rotations[n]
    regressor3.fit(input_fn=lambda: input_fn3(training_set), steps=steps)

def test_set3(n):
    (_, test_set) = rotations[n]
    return regressor3.evaluate(input_fn=lambda: input_fn3(test_set), steps=1)

test_results3 = [train_and_test3(n) for n in range(10)]
# Out:
# WARNING:tensorflow:Change warning: default value of `enable_centered_bias` will change after 2016-10-09. It will be disabled by default.Instructions for keeping existing behaviour:
# Explicitly set `enable_centered_bias` to 'True' if you want to keep existing behaviour.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# WARNING:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, 'keep_checkpoint_max': 5, 'save_summary_steps': 100, 'task': 0, 'master': '', 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , 'num_ps_replicas': 0, 'tf_random_seed': None, 'evaluation_master': '', '_job_name': None, 'cluster_spec': None, 'keep_checkpoint_every_n_hours': 10000, 'save_checkpoints_secs': 600}
# INFO:tensorflow:Setting feature info to {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}
# INFO:tensorflow:Setting targets info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0543374, step = 1
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0359712, step = 101
# INFO:tensorflow:loss = 0.0358777, step = 201
# INFO:tensorflow:loss = 0.035844, step = 301
# INFO:tensorflow:loss = 0.0358408, step = 401
# INFO:tensorflow:Saving checkpoints for 500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0358401.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 500.
# INFO:tensorflow:Saving evaluation summary for 500 step: loss = 0.0338673
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0365439, step = 501
# INFO:tensorflow:Saving checkpoints for 501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0365163, step = 601
# INFO:tensorflow:loss = 0.0364657, step = 701
# INFO:tensorflow:loss = 0.0364655, step = 801
# INFO:tensorflow:loss = 0.0364655, step = 901
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0364654.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 1000.
# INFO:tensorflow:Saving evaluation summary for 1000 step: loss = 0.0277654
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0353027, step = 1001
# INFO:tensorflow:Saving checkpoints for 1001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0352489, step = 1101
# INFO:tensorflow:loss = 0.0352488, step = 1201
# INFO:tensorflow:loss = 0.0352488, step = 1301
# INFO:tensorflow:loss = 0.0352488, step = 1401
# INFO:tensorflow:Saving checkpoints for 1500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0352488.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 1500.
# INFO:tensorflow:Saving evaluation summary for 1500 step: loss = 0.0385188
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0348141, step = 1501
# INFO:tensorflow:Saving checkpoints for 1501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0347903, step = 1601
# INFO:tensorflow:loss = 0.0347903, step = 1701
# INFO:tensorflow:loss = 0.0347903, step = 1801
# INFO:tensorflow:loss = 0.0347903, step = 1901
# INFO:tensorflow:Saving checkpoints for 2000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0347903.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 2000.
# INFO:tensorflow:Saving evaluation summary for 2000 step: loss = 0.0425515
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0352244, step = 2001
# INFO:tensorflow:Saving checkpoints for 2001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0352179, step = 2101
# INFO:tensorflow:loss = 0.0352178, step = 2201
# INFO:tensorflow:loss = 0.0352178, step = 2301
# INFO:tensorflow:loss = 0.0352178, step = 2401
# INFO:tensorflow:Saving checkpoints for 2500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0352178.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 2500.
# INFO:tensorflow:Saving evaluation summary for 2500 step: loss = 0.0388093
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0350962, step = 2501
# INFO:tensorflow:Saving checkpoints for 2501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0350853, step = 2601
# INFO:tensorflow:loss = 0.0350852, step = 2701
# INFO:tensorflow:loss = 0.0350852, step = 2801
# INFO:tensorflow:loss = 0.0350852, step = 2901
# INFO:tensorflow:Saving checkpoints for 3000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0350852.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 3000.
# INFO:tensorflow:Saving evaluation summary for 3000 step: loss = 0.0399307
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0362233, step = 3001
# INFO:tensorflow:Saving checkpoints for 3001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0361999, step = 3101
# INFO:tensorflow:loss = 0.0362001, step = 3201
# INFO:tensorflow:loss = 0.0362, step = 3301
# INFO:tensorflow:loss = 0.0362, step = 3401
# INFO:tensorflow:Saving checkpoints for 3500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0361998.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 3500.
# INFO:tensorflow:Saving evaluation summary for 3500 step: loss = 0.0299502
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0351379, step = 3501
# INFO:tensorflow:Saving checkpoints for 3501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0351324, step = 3601
# INFO:tensorflow:loss = 0.0351324, step = 3701
# INFO:tensorflow:loss = 0.0351324, step = 3801
# INFO:tensorflow:loss = 0.0351324, step = 3901
# INFO:tensorflow:Saving checkpoints for 4000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0351324.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 4000.
# INFO:tensorflow:Saving evaluation summary for 4000 step: loss = 0.0394706
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.0360435, step = 4001
# INFO:tensorflow:Saving checkpoints for 4001 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0360217, step = 4101
# INFO:tensorflow:loss = 0.0360212, step = 4201
# INFO:tensorflow:loss = 0.0360211, step = 4301
# INFO:tensorflow:loss = 0.0360211, step = 4401
# INFO:tensorflow:Saving checkpoints for 4500 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0360211.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 4500.
# INFO:tensorflow:Saving evaluation summary for 4500 step: loss = 0.0315967
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(900,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(900,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Create CheckpointSaverHook
# INFO:tensorflow:loss = 0.035645, step = 4501
# INFO:tensorflow:Saving checkpoints for 4501 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:loss = 0.0356311, step = 4601
# INFO:tensorflow:loss = 0.035631, step = 4701
# INFO:tensorflow:loss = 0.0356309, step = 4801
# INFO:tensorflow:loss = 0.0356309, step = 4901
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0356309.
# WARNING:tensorflow:Given features: {'c': <tf.Tensor 'Const:0' shape=(100,) dtype=float64>}, required signatures: {'c': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False)}.
# WARNING:tensorflow:Given targets: Tensor("Const_1:0", shape=(100,), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(900)]), is_sparse=False).
# INFO:tensorflow:Transforming feature_column _RealValuedColumn(column_name='c', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# INFO:tensorflow:Restored model from /var/folders/0d/xlt_41kx1rl06nd42vsmm0jc0000gp/T/tmp9jaauchl
# INFO:tensorflow:Eval steps [0,1) for training step 5000.
# INFO:tensorflow:Saving evaluation summary for 5000 step: loss = 0.0349779

# %%
test_results3
# Out:
# [{'global_step': 500, 'loss': 0.033867285},
#  {'global_step': 1000, 'loss': 0.027765421},
#  {'global_step': 1500, 'loss': 0.03851876},
#  {'global_step': 2000, 'loss': 0.042551499},
#  {'global_step': 2500, 'loss': 0.038809326},
#  {'global_step': 3000, 'loss': 0.039930727},
#  {'global_step': 3500, 'loss': 0.029950194},
#  {'global_step': 4000, 'loss': 0.039470643},
#  {'global_step': 4500, 'loss': 0.03159669},
#  {'global_step': 5000, 'loss': 0.034977876}]
